# %%
#  National Health Interview Survey (NHIS) Adult Summary Health Statistics
#  URL : https://catalog.data.gov/dataset/nhis-adult-summary-health-statistics-b5ce9

# %%
import json

def filter_by_year(file_path:int, year:int) -> dict:
  with open(file_path, 'w') as f:
    json_data = json.load(f)

    columns = json_data["meta"]["view"]['columns']
    col_names = [name["name"] for name in columns]
    data = json_data["data"]
    filtered_data = [record for record in data if record[-1]==str(year)]

    json_data = {"column_names": col_names, 
                    f"data_{year}": filtered_data} 
    return json_data

# %%
if __name__ == "__main__":
    year = 2019
    file_path = "../Data/nhis.json" 
    result = filter_by_year(file_path, year)

    # Writing JSON
    with open(f"data_{year}.json", "w") as f:
        json.dump(result, f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 year = 2019
#       3 file_path = "../Data/nhis.json"
# ----> 4 result = filter_by_year(file_path, year)
#       6 # Writing JSON
#       7 with open(f"data_{year}.json", "w") as f:
#
# Cell In[4], line 4, in filter_by_year(file_path, year)
#       3 def filter_by_year(file_path:int, year:int) -> dict:
# ----> 4   with open(file_path, 'w') as f:
#       5     json_data = json.load(f)
#       7     columns = json_data["meta"]["view"]['columns']
#
# File ~/tmp/env/eda/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Data/nhis.json'
